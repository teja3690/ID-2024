# %% [markdown]
# # SYSTEMS CHECK
# #### TEJA
# **TARAPATLA**
#
# *Kent State University*

# %% [markdown]
# Goals to pursue in this lesson:
#
# 1. **Efficient Analysis of Complex Real-World Data**: Prove your proficiency with *data analysis* by honing your capacity to extract important insights from unstructured real-world data.
#
# 2. **Using Regression-Based Statistical Learning Approaches**: Learn to apply and interpret regression-based statistical learning approaches to assess your *knowledge of *data analysis*.
#
# 3. **Responsibly Managing Social and Behavioral Information**: Establishing a strong ethical framework for the ethical collection, use, and sharing of social and behavioral data requires careful consideration of privacy, prejudice, and power relations.

# %% [markdown]
# ![image.png](attachment:760d70e4-cc41-4e1b-9a80-431ac69b85a6.png)

# %%
# variable assignment
x = 3
print(x)
# Out:
# 3

# %%
my_list = [2,3,4,5]
my_list
# Out:
# [2, 3, 4, 5]

# %%
my_list = ['now', 'see', 'this']

# %%
# function with print statement
my_name = 'Teja'

# %%
def display_name(x):
    print(x)

# %%
display_name(my_name)
Teja

# %%
# function with return statement
def change_name(x):
    new_name = x + 'new'
    return new_name

# %%
changed_name = change_name('Teja')
changed_name
# Out:
# 'Tejanew'
